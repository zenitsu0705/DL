# %% [markdown]
# <a href="https://colab.research.google.com/github/zenitsu0705/DL/blob/main/week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
model = Sequential()
model.add(Conv2D (filters=96, input_shape=(227,227,3), kernel_size=(11,11), strides=(4,4), padding= 'valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides = (2,2), padding='valid'))
model.add(BatchNormalization())
model.add(Conv2D (filters=256, kernel_size=(11,11), strides=(1,1), padding='valid'))
model.add(Activation ('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D (filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(BatchNormalization())
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation ('relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense (4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))
model.add(Dropout (0.4))
model.add(BatchNormalization())
model.add(Dense(4096))
model.add(Activation ('relu'))
model.add(Dropout (0.4))
model.add(Dense(1000))
model.add(Activation ('relu'))
model.add(Dropout (0.4))
model.add(BatchNormalization())
model.add(Dense(17))
model.add(Activation ('softmax'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 55, 55, 96)        34944
#
#  activation_24 (Activation)  (None, 55, 55, 96)        0
#
#  max_pooling2d_12 (MaxPooli  (None, 27, 27, 96)        0
#  ng2D)
#
#  batch_normalization_24 (Ba  (None, 27, 27, 96)        384
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 17, 17, 256)       2973952
#
#  activation_25 (Activation)  (None, 17, 17, 256)       0
#
#  max_pooling2d_13 (MaxPooli  (None, 8, 8, 256)         0
#  ng2D)
#
#  batch_normalization_25 (Ba  (None, 8, 8, 256)         1024
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 8, 8, 256)         0
#
#  conv2d_22 (Conv2D)          (None, 6, 6, 384)         885120
#
#  batch_normalization_26 (Ba  (None, 6, 6, 384)         1536
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 384)         1327488
#
#  activation_27 (Activation)  (None, 4, 4, 384)         0
#
#  batch_normalization_27 (Ba  (None, 4, 4, 384)         1536
#  tchNormalization)
#
#  conv2d_24 (Conv2D)          (None, 2, 2, 256)         884992
#
#  activation_28 (Activation)  (None, 2, 2, 256)         0
#
#  max_pooling2d_14 (MaxPooli  (None, 1, 1, 256)         0
#  ng2D)
#
#  batch_normalization_28 (Ba  (None, 1, 1, 256)         1024
#  tchNormalization)
#
#  flatten_4 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 4096)              1052672
#
#  activation_29 (Activation)  (None, 4096)              0
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  batch_normalization_29 (Ba  (None, 4096)              16384
#  tchNormalization)
#
#  dense_5 (Dense)             (None, 4096)              16781312
#
#  activation_30 (Activation)  (None, 4096)              0
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_6 (Dense)             (None, 1000)              4097000
#
#  activation_31 (Activation)  (None, 1000)              0
#
#  dropout_6 (Dropout)         (None, 1000)              0
#
#  batch_normalization_30 (Ba  (None, 1000)              4000
#  tchNormalization)
#
#  dense_7 (Dense)             (None, 17)                17017
#
#  activation_32 (Activation)  (None, 17)                0
#
# =================================================================
# Total params: 28080385 (107.12 MB)
# Trainable params: 28067441 (107.07 MB)
# Non-trainable params: 12944 (50.56 KB)
# _________________________________________________________________
